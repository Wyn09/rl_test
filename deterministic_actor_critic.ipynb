# %% [markdown]
# # Off Policy

# %% [markdown]
# ## 算法目的： 为了解决aciton是连续的
# - 输入一个state，输出一个action

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
